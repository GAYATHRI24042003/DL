# %% [markdown]
# <a href="https://colab.research.google.com/github/GAYATHRI24042003/DL/blob/main/NeuralNetwork_dataset(CIFAR_10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

# Load and prepare the training data (CIFAR-10)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
train_dataset = datasets.CIFAR10('data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# Define the model
class Neural(nn.Module):
    def __init__(self):
        super(Neural, self).__init__()
        self.fc1 = nn.Linear(32 * 32 * 3, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)

    def forward(self, x):
        x = x.view(-1, 32 * 32 * 3)  # Flatten the input
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Neural()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

    accuracy = 100 * correct / total
    print('Accuracy after epoch {}: {:.2f}%'.format(epoch, accuracy))
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:02<00:00, 72880218.01it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Train Epoch: 0 [0/50000 (0%)]	Loss: 2.304600
# Train Epoch: 0 [3200/50000 (6%)]	Loss: 1.708766
# Train Epoch: 0 [6400/50000 (13%)]	Loss: 1.753817
# Train Epoch: 0 [9600/50000 (19%)]	Loss: 1.600349
# Train Epoch: 0 [12800/50000 (26%)]	Loss: 1.560002
# Train Epoch: 0 [16000/50000 (32%)]	Loss: 1.101710
# Train Epoch: 0 [19200/50000 (38%)]	Loss: 1.741723
# Train Epoch: 0 [22400/50000 (45%)]	Loss: 1.358055
# Train Epoch: 0 [25600/50000 (51%)]	Loss: 1.332746
# Train Epoch: 0 [28800/50000 (58%)]	Loss: 1.162568
# Train Epoch: 0 [32000/50000 (64%)]	Loss: 1.287172
# Train Epoch: 0 [35200/50000 (70%)]	Loss: 1.145600
# Train Epoch: 0 [38400/50000 (77%)]	Loss: 0.949935
# Train Epoch: 0 [41600/50000 (83%)]	Loss: 0.996064
# Train Epoch: 0 [44800/50000 (90%)]	Loss: 0.602475
# Train Epoch: 0 [48000/50000 (96%)]	Loss: 0.841076
# Accuracy after epoch 0: 50.48%
# ...
